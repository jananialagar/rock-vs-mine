# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#loading dataset
dataframe = pd.read_csv("C:/Users/janan/miniproject/sonardata.csv")

# %%
#to check/display dataset
print(dataframe.head(10))
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# 5  0.0317  0.0956  0.1321  0.1408  0.1674  0.1710  0.0731  0.1401  0.2083
# 6  0.0519  0.0548  0.0842  0.0319  0.1158  0.0922  0.1027  0.0613  0.1465
# 7  0.0223  0.0375  0.0484  0.0475  0.0647  0.0591  0.0753  0.0098  0.0684
# 8  0.0164  0.0173  0.0347  0.0070  0.0187  0.0671  0.1056  0.0697  0.0962
# 9  0.0039  0.0063  0.0152  0.0336  0.0310  0.0284  0.0396  0.0272  0.0323
#
#    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# ...

# %%
#to check no 0f rowsxcol
dataframe.shape
# Out:
# (207, 61)

# %%
#checking missing values
missing_val= dataframe.isna().sum().sum()
print("Missing values in sonardataset: \n",missing_val)
# Out:
# Missing values in sonardataset:
#  0

# %%
# Select features (X) and target variable (y)
X = dataframe.drop('R', axis=1)
y = dataframe['R']

# %%
print(dataframe.columns)
# Out:
# Index(['0.0200', '0.0371', '0.0428', '0.0207', '0.0954', '0.0986', '0.1539',
#        '0.1601', '0.3109', '0.2111', '0.1609', '0.1582', '0.2238', '0.0645',
#        '0.0660', '0.2273', '0.3100', '0.2999', '0.5078', '0.4797', '0.5783',
#        '0.5071', '0.4328', '0.5550', '0.6711', '0.6415', '0.7104', '0.8080',
#        '0.6791', '0.3857', '0.1307', '0.2604', '0.5121', '0.7547', '0.8537',
#        '0.8507', '0.6692', '0.6097', '0.4943', '0.2744', '0.0510', '0.2834',
#        '0.2825', '0.4256', '0.2641', '0.1386', '0.1051', '0.1343', '0.0383',
#        '0.0324', '0.0232', '0.0027', '0.0065', '0.0159', '0.0072', '0.0167',
#        '0.0180', '0.0084', '0.0090', '0.0032', 'R'],
#       dtype='object')

# %%
y = pd.get_dummies(y, drop_first = True) 
y.head(100)
# Out:
#     R
# 0   1
# 1   1
# 2   1
# 3   1
# 4   1
# .. ..
# 95  1
# 96  0
# 97  0
# 98  0
# 99  0
#
# [100 rows x 1 columns]

# %%
y.value_counts()
# Out:
# R
# 0    111
# 1     96
# dtype: int64

# %%
#splitting dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1, stratify=y)

# %%
X_train.shape, X_test.shape
# Out:
# ((155, 60), (52, 60))

# %%
# Standardize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_train
# Out:
# array([[ 3.04680779,  1.430001  ,  0.59911446, ...,  1.94886651,
#          2.10663   , -0.46358137],
#        [-0.67923839, -0.57298835, -1.13597132, ..., -0.20175219,
#         -0.79419972, -0.22844056],
#        [-0.04264985, -0.4405326 ,  0.57534617, ...,  1.31164615,
#          2.26689684,  2.12296752],
#        ...,
#        [-0.74156174, -0.99943124, -0.44074859, ..., -0.26547422,
#         -0.84227977, -0.24803563],
#        [ 3.85701138,  2.53487577,  1.3032503 , ...,  0.99303598,
#         -0.16915906,  0.41819666],
#        [ 0.21999856, -0.50837579, -0.46748793, ...,  0.8496614 ,
#         -0.44161268, -0.46358137]])

# %%
#visualization
dataframe.hist(sharex=False, sharey=False, xlabelsize=1, ylabelsize=1)
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 #visualization
#       2 dataframe.hist(sharex=False, sharey=False, xlabelsize=1, ylabelsize=1)
# ----> 3 pyplot.show()
#
# NameError: name 'pyplot' is not defined
